# %%
# Reading the dataset
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/analyticsindiamagazine/MocksDatasets/main/gender_classification.csv')
data.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
# Shape of the data
data.shape
# Out:
# (5001, 8)

# %% [markdown]
# #**Data Preprocessing**

# %%
# Counting labels
data['gender'].value_counts()
# Out:
# Female    2501
# Male      2500
# Name: gender, dtype: int64

# %%
# Lableeing with numerical values
data['gender'] = data['gender'].replace(to_replace=['Female', 'Male'], value=[0, 1])
data['gender'].value_counts()
# Out:
# 0    2501
# 1    2500
# Name: gender, dtype: int64

# %%
# Defining input and output features
X = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
# Creating training and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Shape of train-test sets
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4000, 7)
# (4000,)
# (1001, 7)
# (1001,)

# %% [markdown]
# # **Defining a Neural Network Classifier**

# %%
# Libraries for neural networks
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# Defining the neural network model
model = Sequential()
model.add(Dense(12, input_dim=7, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Summary of the neural network model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                96
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 209
# Trainable params: 209
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Stochastic Gradient Descent**

# %%
# Defining Stochastic Gradient Descent as optimizer
opt = keras.optimizers.SGD(learning_rate=0.01)

# %%
# Compiling the classifier
model.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# Training the classifier
model.fit(X_train, y_train, epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# 400/400 [==============================] - 2s 1ms/step - loss: 0.5833 - accuracy: 0.7315
# Epoch 2/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2474 - accuracy: 0.9205
# Epoch 3/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1418 - accuracy: 0.9488
# Epoch 4/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1354 - accuracy: 0.9482
# Epoch 5/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1198 - accuracy: 0.9517
# Epoch 6/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1256 - accuracy: 0.9498
# Epoch 7/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1156 - accuracy: 0.9563
# Epoch 8/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1172 - accuracy: 0.9540
# Epoch 9/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1140 - accuracy: 0.9548
# Epoch 10/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1138 - accuracy: 0.9528
# Epoch 11/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1080 - accuracy: 0.9553
# Epoch 12/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1068 - accuracy: 0.9597
# Epoch 13/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1080 - accuracy: 0.9563
# Epoch 14/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1081 - accuracy: 0.9540
# Epoch 15/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1139 - accuracy: 0.9510
# Epoch 16/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1055 - accuracy: 0.9540
# Epoch 17/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1001 - accuracy: 0.9600
# Epoch 18/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1040 - accuracy: 0.9557
# Epoch 19/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1058 - accuracy: 0.9545
# Epoch 20/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0989 - accuracy: 0.9588

# %%
# Checking training and test accuracies
sgd_acc = model.evaluate(X_train, y_train)
print ("Training Accuracy: %.2f%%\n" % (sgd_acc[1]*100))
sgd_loss = model.evaluate(X_test, y_test)
print ("Testing Accuracy: %.2f%%\n" % (sgd_loss[1]*100))
# Out:
# 125/125 [==============================] - 1s 3ms/step - loss: 0.1003 - accuracy: 0.9567
# Training Accuracy: 95.67%
#
# 32/32 [==============================] - 1s 5ms/step - loss: 0.1298 - accuracy: 0.9481
# Testing Accuracy: 94.81%

# %% [markdown]
# # **Adam (Adaptive Moment Estimation)**

# %%
# Initializing the model
model_adam = Sequential()
model_adam.add(Dense(12, input_dim=7, activation='relu'))
model_adam.add(Dense(8, activation='relu'))
model_adam.add(Dense(1, activation='sigmoid'))

# %%
# Defining Adam as optimizer
opt = keras.optimizers.Adam(learning_rate=0.01)

# %%
# Compiling the classifier
model_adam.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# Training the classifier
model_adam.fit(X_train, y_train, epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1475 - accuracy: 0.9448
# Epoch 2/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1049 - accuracy: 0.9528
# Epoch 3/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1023 - accuracy: 0.9592
# Epoch 4/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0976 - accuracy: 0.9590
# Epoch 5/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0952 - accuracy: 0.9588
# Epoch 6/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0965 - accuracy: 0.9545
# Epoch 7/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0911 - accuracy: 0.9553
# Epoch 8/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0899 - accuracy: 0.9565
# Epoch 9/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0902 - accuracy: 0.9595
# Epoch 10/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0881 - accuracy: 0.9580
# Epoch 11/20
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0885 - accuracy: 0.9595
# Epoch 12/20
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0889 - accuracy: 0.9570
# Epoch 13/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0912 - accuracy: 0.9572
# Epoch 14/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0891 - accuracy: 0.9607
# Epoch 15/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0862 - accuracy: 0.9607
# Epoch 16/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0858 - accuracy: 0.9613
# Epoch 17/20
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0844 - accuracy: 0.9582
# Epoch 18/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0860 - accuracy: 0.9643
# Epoch 19/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0865 - accuracy: 0.9615
# Epoch 20/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0857 - accuracy: 0.9582

# %%
# Checking training and test accuracies
adam_acc = model_adam.evaluate(X_train, y_train)
print ("Training Accuracy: %.2f%%\n" % (adam_acc[1]*100))
adam_loss = model_adam.evaluate(X_test, y_test)
print ("Testing Accuracy: %.2f%%\n" % (adam_loss[1]*100))
# Out:
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 0.9682
# Training Accuracy: 96.82%
#
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9590
# Testing Accuracy: 95.90%

# %% [markdown]
# # **AdaGrad (Adaptive Gradient)**

# %%
# Initializing the model
model_adag = Sequential()
model_adag.add(Dense(12, input_dim=7, activation='relu'))
model_adag.add(Dense(8, activation='relu'))
model_adag.add(Dense(1, activation='sigmoid'))

# %%
# Defining AdaGrad as optimizer
opt = keras.optimizers.Adagrad(learning_rate=0.01)

# %%
# Compiling the classifier
model_adag.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# Training the classifier
model_adag.fit(X_train, y_train, epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6025 - accuracy: 0.7688
# Epoch 2/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3923 - accuracy: 0.9293
# Epoch 3/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2579 - accuracy: 0.9507
# Epoch 4/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1946 - accuracy: 0.9530
# Epoch 5/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1625 - accuracy: 0.9528
# Epoch 6/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1442 - accuracy: 0.9528
# Epoch 7/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1326 - accuracy: 0.9510
# Epoch 8/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1243 - accuracy: 0.9523
# Epoch 9/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1185 - accuracy: 0.9505
# Epoch 10/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1140 - accuracy: 0.9503
# Epoch 11/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1104 - accuracy: 0.9495
# Epoch 12/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1076 - accuracy: 0.9503
# Epoch 13/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1053 - accuracy: 0.9523
# Epoch 14/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1033 - accuracy: 0.9513
# Epoch 15/20
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1018 - accuracy: 0.9498
# Epoch 16/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1003 - accuracy: 0.9498
# Epoch 17/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0991 - accuracy: 0.9495
# Epoch 18/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0981 - accuracy: 0.9503
# Epoch 19/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0973 - accuracy: 0.9498
# Epoch 20/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0964 - accuracy: 0.9510

# %%
# Checking training and test accuracies
agd_acc = model_adag.evaluate(X_train, y_train)
print ("Training Accuracy: %.2f%%\n" % (agd_acc[1]*100))
agd_loss = model_adag.evaluate(X_test, y_test)
print ("Testing Accuracy: %.2f%%\n" % (agd_loss[1]*100))
# Out:
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0957 - accuracy: 0.9503
# Training Accuracy: 95.03%
#
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1175 - accuracy: 0.9391
# Testing Accuracy: 93.91%

# %% [markdown]
# # **RMSProp (Root Mean Squared Propagation)**

# %%
# Initializing the model
model_RMSp = Sequential()
model_RMSp.add(Dense(12, input_dim=7, activation='relu'))
model_RMSp.add(Dense(8, activation='relu'))
model_RMSp.add(Dense(1, activation='sigmoid'))

# %%
# Defining RMSProp as optimizer
opt = keras.optimizers.RMSprop(learning_rate=0.01)

# %%
# Compiling the classifier
model_RMSp.compile(loss='binary_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# Training the classifier
model_RMSp.fit(X_train, y_train, epochs=20, batch_size=10)
# Out:
# Epoch 1/20
# 400/400 [==============================] - 2s 2ms/step - loss: 0.1443 - accuracy: 0.9477
# Epoch 2/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1180 - accuracy: 0.9550
# Epoch 3/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1076 - accuracy: 0.9553
# Epoch 4/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1056 - accuracy: 0.9575
# Epoch 5/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1049 - accuracy: 0.9592
# Epoch 6/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1016 - accuracy: 0.9550
# Epoch 7/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0977 - accuracy: 0.9565
# Epoch 8/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0971 - accuracy: 0.9595
# Epoch 9/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1024 - accuracy: 0.9570
# Epoch 10/20
# 400/400 [==============================] - 1s 3ms/step - loss: 0.0969 - accuracy: 0.9572
# Epoch 11/20
# 400/400 [==============================] - 1s 3ms/step - loss: 0.1012 - accuracy: 0.9588
# Epoch 12/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0980 - accuracy: 0.9595
# Epoch 13/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1013 - accuracy: 0.9595
# Epoch 14/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0940 - accuracy: 0.9570
# Epoch 15/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1034 - accuracy: 0.9555
# Epoch 16/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1022 - accuracy: 0.9590
# Epoch 17/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0996 - accuracy: 0.9580
# Epoch 18/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1000 - accuracy: 0.9610
# Epoch 19/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.0998 - accuracy: 0.9615
# Epoch 20/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.1008 - accuracy: 0.9592

# %%
# Checking training and test accuracies
rms_acc = model_RMSp.evaluate(X_train, y_train)
print ("Training Accuracy: %.2f%%\n" % (rms_acc[1]*100))
rms_loss = model_RMSp.evaluate(X_test, y_test)
print ("Testing Accuracy: %.2f%%\n" % (rms_loss[1]*100))
# Out:
# 125/125 [==============================] - 0s 1ms/step - loss: 0.1523 - accuracy: 0.9287
# Training Accuracy: 92.87%
#
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2118 - accuracy: 0.9231
# Testing Accuracy: 92.31%

# %%
# Summarizing all
opt_summary = pd.DataFrame(data={'Optimizers' : ['SGD', 'Adam', 'AdaGrad', 'RMSProp'],
                   'Accuracy' : [sgd_acc[1], adam_acc[1], agd_acc[1], rms_acc[1]],
                   'Loss' : [sgd_loss[0], adam_loss[0], agd_loss[0], rms_loss[0]],
                  })
opt_summary
# Out:
#   Optimizers  Accuracy      Loss
# 0        SGD   0.95675  0.129840
# 1       Adam   0.96825  0.104717
# 2    AdaGrad   0.95025  0.117464
# 3    RMSProp   0.92875  0.211801
